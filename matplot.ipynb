# %%
import numpy as np

import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 3, figsize=(15, 12))
axs = axs.flatten()

axs[0].plot(x, y, marker='o', color='tab:blue')
axs[0].set_title('Line chart')
axs[0].set_xlabel('X')
axs[0].set_ylabel('Y')

axs[1].bar(categories, values, color=['tab:orange', 'tab:green', 'tab:red', 'tab:purple'])
axs[1].set_title('Bar chart')

axs[2].scatter(x, z[: len(x)], c=z[: len(x)], cmap='viridis', edgecolor='k', alpha=0.8)
axs[2].set_title('Scatter plot')
axs[2].set_xlabel('X')
axs[2].set_ylabel('Z')

axs[3].hist(z, bins=20, color='tab:cyan', edgecolor='black')
axs[3].set_title('Histogram')

axs[4].pie(values, labels=categories, autopct='%1.1f%%', startangle=90,
           colors=['tab:blue', 'tab:orange', 'tab:green', 'tab:red'])
axs[4].set_title('Pie chart')

axs[5].boxplot([area1, area2], labels=['area1', 'area2'])
axs[5].set_title('Box plot')

axs[6].stackplot(x, area1, area2, labels=['area1', 'area2'], alpha=0.7)
axs[6].set_title('Stackplot')

axs[7].fill_between(x, y, color='tab:orange', alpha=0.4)
axs[7].plot(x, y, color='tab:orange')
axs[7].set_title('Area chart')

axs[8].plot(np.cumsum(np.random.randn(50)), color='tab:gray')
axs[8].set_title('Sample trend')

for ax in axs:
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\City College\AppData\Local\Temp\ipykernel_15140\1181480261.py:28: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axs[5].boxplot([area1, area2], labels=['area1', 'area2'])
